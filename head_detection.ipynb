# %%
import os
import cv2
import torch
import csv
import torchvision.ops as ops
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort

# ─── 0. Configuration ─────────────────────────────────────────────────────────
input_folder  = "./videos"
output_folder = "./output_videos"
os.makedirs(output_folder, exist_ok=True)

SKIP     = 1
IMG_SIZE = 512
device   = 0

# ─── 1. Prepare CSV log ───────────────────────────────────────────────────────
log_path = os.path.join(output_folder, "tracking_log.csv")
with open(log_path, "w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["video", "frame_id", "track_id", "x1", "y1", "x2", "y2"])

# ─── 2. Load models + tracker ─────────────────────────────────────────────────
head_model = YOLO("medium.pt")
body_model = YOLO("yolov8n.pt")
tracker    = DeepSort(max_age=30)

# ─── 3. Process videos 01.mp4 → 20.mp4 ────────────────────────────────────────
for i in range(1, 21):
    vid_name = f"{i:02}.mp4"
    in_path  = os.path.join(input_folder, vid_name)
    out_path = os.path.join(output_folder, f"tracked_{vid_name}")

    if not os.path.isfile(in_path):
        print(f"  Skipping missing {vid_name}")
        continue

    print(f"  Processing {vid_name}")
    cap = cv2.VideoCapture(in_path)
    fps    = cap.get(cv2.CAP_PROP_FPS) or 30
    w      = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    h      = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    out    = cv2.VideoWriter(out_path, fourcc, fps, (w, h))

    frame_id = 0
    tracks   = []  # to keep last tracks between skips

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # ─── A. Inference & tracking every SKIP frames ────────────────
        if frame_id % SKIP == 0:
            # Detect heads and bodies
            head_res = head_model(frame, conf=0.15, iou=0.5, imgsz=IMG_SIZE)[0]
            body_res = body_model(frame, conf=0.2,  iou=0.5, imgsz=IMG_SIZE)[0]

            # Collect detections: [x1,y1,x2,y2,conf,cls]
            dets = []
            for x1,y1,x2,y2,conf,cls in head_res.boxes.data.tolist():
                dets.append([x1,y1,x2,y2,conf,1])
            for x1,y1,x2,y2,conf,cls in body_res.boxes.data.tolist():
                if int(cls) == 0:
                    dets.append([x1,y1,x2,y2,conf,0])   

            # NMS
            if dets:
                dt   = torch.tensor(dets)
                keep = ops.nms(dt[:,:4], dt[:,4], iou_threshold=0.5)
                final = dt[keep]
            else:
                final = torch.empty((0,6))

            # Prep for DeepSORT
            to_track = [
                ([x1, y1, x2-x1, y2-y1], float(conf), int(cls))
                for x1,y1,x2,y2,conf,cls in final.tolist()
            ]

            # Update tracker
            tracks = tracker.update_tracks(to_track, frame=frame)

        # ─── B. Draw & log every confirmed track ────────────────────────
        with open(log_path, "a", newline="") as csvfile:
            writer = csv.writer(csvfile)
            for tr in tracks:
                if not tr.is_confirmed():
                    continue
                x1, y1, x2, y2 = map(int, tr.to_ltrb())
                # draw box
                cls   = getattr(tr, "det_class", None)
                color = (255,0,0) if cls==0 else (0,255,0)
                cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
                # log bbox coords
                writer.writerow([vid_name, frame_id, tr.track_id, x1, y1, x2, y2])

        # ─── C. Always write every frame ────────────────────────────────
        out.write(frame)
        frame_id += 1

    cap.release()
    out.release()
    print(f"  Saved {out_path}")

print(f"  Done! Log saved at {log_path}")
# Out:
#   Processing 01.mp4
#
# 0: 288x512 1 head, 48.0ms
# Speed: 5.3ms preprocess, 48.0ms inference, 3.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 23.6ms
# Speed: 3.0ms preprocess, 23.6ms inference, 3.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 109.9ms
# Speed: 4.0ms preprocess, 109.9ms inference, 5.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 16.7ms
# Speed: 2.2ms preprocess, 16.7ms inference, 7.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 39.5ms
# Speed: 2.7ms preprocess, 39.5ms inference, 4.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 14.7ms
# Speed: 2.2ms preprocess, 14.7ms inference, 5.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 71.2ms
# Speed: 4.9ms preprocess, 71.2ms inference, 3.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 16.2ms
# Speed: 2.8ms preprocess, 16.2ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 72.9ms
# Speed: 2.8ms preprocess, 72.9ms inference, 2.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 13.7ms
# Speed: 6.3ms preprocess, 13.7ms inference, 4.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 69.6ms
# Speed: 3.2ms preprocess, 69.6ms inference, 3.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 13.7ms
# Speed: 3.3ms preprocess, 13.7ms inference, 4.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 68.4ms
# Speed: 2.4ms preprocess, 68.4ms inference, 3.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 17.0ms
# Speed: 4.0ms preprocess, 17.0ms inference, 4.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 67.6ms
# Speed: 2.9ms preprocess, 67.6ms inference, 3.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 3.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 33.2ms
# Speed: 1.9ms preprocess, 33.2ms inference, 5.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 10.5ms
# Speed: 2.1ms preprocess, 10.5ms inference, 4.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 32.8ms
# Speed: 2.1ms preprocess, 32.8ms inference, 4.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 14.1ms
# Speed: 2.6ms preprocess, 14.1ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 34.5ms
# Speed: 2.4ms preprocess, 34.5ms inference, 3.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 14.9ms
# Speed: 2.5ms preprocess, 14.9ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 31.6ms
# Speed: 2.4ms preprocess, 31.6ms inference, 2.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 10.3ms
# Speed: 2.5ms preprocess, 10.3ms inference, 4.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 31.1ms
# Speed: 2.4ms preprocess, 31.1ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 14.1ms
# Speed: 2.6ms preprocess, 14.1ms inference, 4.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 30.5ms
# Speed: 3.1ms preprocess, 30.5ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 10.3ms
# Speed: 1.9ms preprocess, 10.3ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 30.3ms
# Speed: 2.4ms preprocess, 30.3ms inference, 3.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 25.2ms
# Speed: 2.7ms preprocess, 25.2ms inference, 6.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 33.3ms
# Speed: 2.5ms preprocess, 33.3ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 persons, 25.9ms
# Speed: 2.7ms preprocess, 25.9ms inference, 11.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 64.0ms
# Speed: 2.8ms preprocess, 64.0ms inference, 3.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 persons, 26.0ms
# Speed: 2.0ms preprocess, 26.0ms inference, 13.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 42.7ms
# Speed: 5.4ms preprocess, 42.7ms inference, 3.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 10.8ms
# Speed: 2.6ms preprocess, 10.8ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 27.9ms
# Speed: 2.3ms preprocess, 27.9ms inference, 5.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 14.4ms
# Speed: 2.3ms preprocess, 14.4ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 heads, 28.2ms
# Speed: 2.4ms preprocess, 28.2ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 17.1ms
# Speed: 2.1ms preprocess, 17.1ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 27.8ms
# Speed: 2.0ms preprocess, 27.8ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 17.5ms
# Speed: 2.6ms preprocess, 17.5ms inference, 5.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 heads, 27.2ms
# Speed: 2.3ms preprocess, 27.2ms inference, 3.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 9.4ms
# Speed: 1.9ms preprocess, 9.4ms inference, 2.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 32.1ms
# Speed: 2.0ms preprocess, 32.1ms inference, 8.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 41.8ms
# Speed: 5.7ms preprocess, 41.8ms inference, 27.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 42.7ms
# Speed: 2.5ms preprocess, 42.7ms inference, 4.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 29.0ms
# Speed: 2.6ms preprocess, 29.0ms inference, 5.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 29.6ms
# Speed: 2.5ms preprocess, 29.6ms inference, 5.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 25.8ms
# Speed: 2.9ms preprocess, 25.8ms inference, 4.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 28.1ms
# Speed: 3.3ms preprocess, 28.1ms inference, 4.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 15.6ms
# Speed: 3.1ms preprocess, 15.6ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 heads, 26.9ms
# Speed: 2.3ms preprocess, 26.9ms inference, 4.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 1 traffic light, 14.4ms
# Speed: 2.4ms preprocess, 14.4ms inference, 3.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 35.9ms
# Speed: 4.4ms preprocess, 35.9ms inference, 9.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 1 traffic light, 13.7ms
# Speed: 2.3ms preprocess, 13.7ms inference, 2.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 25.6ms
# Speed: 2.5ms preprocess, 25.6ms inference, 3.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 14.4ms
# Speed: 2.0ms preprocess, 14.4ms inference, 3.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 heads, 25.3ms
# Speed: 3.5ms preprocess, 25.3ms inference, 2.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 14.3ms
# Speed: 2.0ms preprocess, 14.3ms inference, 3.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 24.5ms
# Speed: 2.2ms preprocess, 24.5ms inference, 3.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 16.1ms
# Speed: 1.6ms preprocess, 16.1ms inference, 5.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 24.4ms
# Speed: 3.7ms preprocess, 24.4ms inference, 4.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 16.1ms
# Speed: 2.3ms preprocess, 16.1ms inference, 4.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 6 heads, 24.5ms
# Speed: 2.8ms preprocess, 24.5ms inference, 5.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 19.4ms
# Speed: 2.0ms preprocess, 19.4ms inference, 4.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 heads, 27.2ms
# Speed: 2.7ms preprocess, 27.2ms inference, 4.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 18.4ms
# Speed: 2.1ms preprocess, 18.4ms inference, 3.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 27.8ms
# Speed: 2.8ms preprocess, 27.8ms inference, 2.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 14.4ms
# Speed: 1.8ms preprocess, 14.4ms inference, 4.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 25.0ms
# Speed: 2.5ms preprocess, 25.0ms inference, 4.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 17.5ms
# Speed: 3.7ms preprocess, 17.5ms inference, 4.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 25.2ms
# Speed: 2.8ms preprocess, 25.2ms inference, 3.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 16.9ms
# Speed: 3.3ms preprocess, 16.9ms inference, 4.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 25.0ms
# Speed: 2.2ms preprocess, 25.0ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 17.1ms
# Speed: 1.7ms preprocess, 17.1ms inference, 3.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 25.6ms
# Speed: 2.7ms preprocess, 25.6ms inference, 3.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 13.6ms
# Speed: 3.2ms preprocess, 13.6ms inference, 4.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 25.8ms
# Speed: 1.8ms preprocess, 25.8ms inference, 3.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 14.9ms
# Speed: 2.4ms preprocess, 14.9ms inference, 4.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 25.8ms
# Speed: 1.9ms preprocess, 25.8ms inference, 3.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 14.8ms
# Speed: 2.3ms preprocess, 14.8ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 25.2ms
# Speed: 2.1ms preprocess, 25.2ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 13.6ms
# Speed: 2.4ms preprocess, 13.6ms inference, 3.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 25.3ms
# Speed: 2.0ms preprocess, 25.3ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 11.7ms
# Speed: 2.2ms preprocess, 11.7ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 27.1ms
# Speed: 1.9ms preprocess, 27.1ms inference, 2.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 12.7ms
# Speed: 2.2ms preprocess, 12.7ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 27.9ms
# Speed: 2.5ms preprocess, 27.9ms inference, 3.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 15.4ms
# Speed: 2.5ms preprocess, 15.4ms inference, 3.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 25.3ms
# Speed: 2.7ms preprocess, 25.3ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 12.4ms
# Speed: 2.3ms preprocess, 12.4ms inference, 2.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 25.4ms
# Speed: 2.4ms preprocess, 25.4ms inference, 4.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 14.1ms
# Speed: 2.7ms preprocess, 14.1ms inference, 5.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 26.4ms
# Speed: 1.8ms preprocess, 26.4ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 14.2ms
# Speed: 2.2ms preprocess, 14.2ms inference, 4.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 25.5ms
# Speed: 2.6ms preprocess, 25.5ms inference, 4.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 13.1ms
# Speed: 2.2ms preprocess, 13.1ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 26.4ms
# Speed: 2.0ms preprocess, 26.4ms inference, 3.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 63.6ms
# Speed: 2.1ms preprocess, 63.6ms inference, 3.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 26.6ms
# Speed: 2.3ms preprocess, 26.6ms inference, 4.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 13.9ms
# Speed: 2.1ms preprocess, 13.9ms inference, 3.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 53.2ms
# Speed: 3.2ms preprocess, 53.2ms inference, 6.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 25.7ms
# Speed: 2.8ms preprocess, 25.7ms inference, 4.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 27.6ms
# Speed: 2.7ms preprocess, 27.6ms inference, 2.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 14.2ms
# Speed: 2.2ms preprocess, 14.2ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 26.5ms
# Speed: 2.5ms preprocess, 26.5ms inference, 3.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 15.5ms
# Speed: 2.2ms preprocess, 15.5ms inference, 3.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 25.3ms
# Speed: 2.6ms preprocess, 25.3ms inference, 3.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 18.2ms
# Speed: 2.2ms preprocess, 18.2ms inference, 5.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 35.4ms
# Speed: 2.8ms preprocess, 35.4ms inference, 4.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 29.4ms
# Speed: 5.4ms preprocess, 29.4ms inference, 6.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 30.2ms
# Speed: 2.5ms preprocess, 30.2ms inference, 3.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 25.0ms
# Speed: 2.6ms preprocess, 25.0ms inference, 6.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 27.6ms
# Speed: 2.7ms preprocess, 27.6ms inference, 4.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 17.1ms
# Speed: 2.3ms preprocess, 17.1ms inference, 7.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 heads, 29.7ms
# Speed: 2.7ms preprocess, 29.7ms inference, 5.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 17.8ms
# Speed: 2.9ms preprocess, 17.8ms inference, 4.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 heads, 27.0ms
# Speed: 2.6ms preprocess, 27.0ms inference, 3.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 16.7ms
# Speed: 2.2ms preprocess, 16.7ms inference, 3.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 27.6ms
# Speed: 2.1ms preprocess, 27.6ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 15.4ms
# Speed: 2.0ms preprocess, 15.4ms inference, 11.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 heads, 28.2ms
# Speed: 2.3ms preprocess, 28.2ms inference, 4.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 21.4ms
# Speed: 3.4ms preprocess, 21.4ms inference, 3.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 heads, 28.5ms
# Speed: 2.9ms preprocess, 28.5ms inference, 5.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 15.4ms
# Speed: 2.9ms preprocess, 15.4ms inference, 4.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 heads, 28.3ms
# Speed: 3.3ms preprocess, 28.3ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 11.8ms
# Speed: 1.7ms preprocess, 11.8ms inference, 2.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 26.6ms
# Speed: 2.1ms preprocess, 26.6ms inference, 5.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 11.4ms
# Speed: 2.5ms preprocess, 11.4ms inference, 5.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 27.7ms
# Speed: 2.2ms preprocess, 27.7ms inference, 4.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 11.9ms
# Speed: 2.2ms preprocess, 11.9ms inference, 3.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 26.2ms
# Speed: 2.5ms preprocess, 26.2ms inference, 3.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 11.5ms
# Speed: 2.1ms preprocess, 11.5ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 26.9ms
# Speed: 2.6ms preprocess, 26.9ms inference, 3.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 13.7ms
# Speed: 2.2ms preprocess, 13.7ms inference, 3.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 heads, 29.6ms
# Speed: 2.2ms preprocess, 29.6ms inference, 3.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 13.6ms
# Speed: 2.0ms preprocess, 13.6ms inference, 4.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 25.2ms
# Speed: 2.3ms preprocess, 25.2ms inference, 4.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 12.5ms
# Speed: 2.9ms preprocess, 12.5ms inference, 2.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 26.2ms
# Speed: 2.4ms preprocess, 26.2ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 12.5ms
# Speed: 2.5ms preprocess, 12.5ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 24.3ms
# Speed: 2.4ms preprocess, 24.3ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 12.5ms
# Speed: 2.1ms preprocess, 12.5ms inference, 3.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 24.3ms
# Speed: 2.1ms preprocess, 24.3ms inference, 3.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 11.5ms
# Speed: 2.1ms preprocess, 11.5ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 24.4ms
# Speed: 1.8ms preprocess, 24.4ms inference, 3.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 14.3ms
# Speed: 1.9ms preprocess, 14.3ms inference, 3.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 24.4ms
# Speed: 1.8ms preprocess, 24.4ms inference, 5.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 12.4ms
# Speed: 2.3ms preprocess, 12.4ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 24.3ms
# Speed: 3.0ms preprocess, 24.3ms inference, 3.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 12.0ms
# Speed: 1.8ms preprocess, 12.0ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 25.6ms
# Speed: 1.9ms preprocess, 25.6ms inference, 3.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 15.5ms
# Speed: 2.2ms preprocess, 15.5ms inference, 4.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 24.5ms
# Speed: 2.1ms preprocess, 24.5ms inference, 4.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 18.3ms
# Speed: 2.0ms preprocess, 18.3ms inference, 4.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 25.6ms
# Speed: 2.3ms preprocess, 25.6ms inference, 3.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 1 traffic light, 12.4ms
# Speed: 1.9ms preprocess, 12.4ms inference, 3.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 26.6ms
# Speed: 1.9ms preprocess, 26.6ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 17.0ms
# Speed: 2.3ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 24.6ms
# Speed: 2.7ms preprocess, 24.6ms inference, 3.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 25.8ms
# Speed: 2.6ms preprocess, 25.8ms inference, 5.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 26.6ms
# Speed: 2.4ms preprocess, 26.6ms inference, 3.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 21.5ms
# Speed: 2.5ms preprocess, 21.5ms inference, 3.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 24.2ms
# Speed: 2.5ms preprocess, 24.2ms inference, 3.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 21.5ms
# Speed: 2.4ms preprocess, 21.5ms inference, 4.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 50.3ms
# Speed: 2.5ms preprocess, 50.3ms inference, 6.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 48.8ms
# Speed: 3.2ms preprocess, 48.8ms inference, 4.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 44.8ms
# Speed: 2.3ms preprocess, 44.8ms inference, 5.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 25.5ms
# Speed: 2.0ms preprocess, 25.5ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 27.9ms
# Speed: 2.6ms preprocess, 27.9ms inference, 3.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 18.1ms
# Speed: 2.4ms preprocess, 18.1ms inference, 5.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 29.7ms
# Speed: 2.1ms preprocess, 29.7ms inference, 6.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 21.6ms
# Speed: 2.7ms preprocess, 21.6ms inference, 3.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 29.9ms
# Speed: 3.0ms preprocess, 29.9ms inference, 4.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 21.8ms
# Speed: 2.0ms preprocess, 21.8ms inference, 6.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 28.7ms
# Speed: 2.8ms preprocess, 28.7ms inference, 3.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 18.1ms
# Speed: 1.7ms preprocess, 18.1ms inference, 3.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 28.6ms
# Speed: 3.2ms preprocess, 28.6ms inference, 6.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 19.9ms
# Speed: 1.9ms preprocess, 19.9ms inference, 4.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 29.0ms
# Speed: 2.6ms preprocess, 29.0ms inference, 3.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 22.4ms
# Speed: 3.3ms preprocess, 22.4ms inference, 3.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 30.1ms
# Speed: 3.1ms preprocess, 30.1ms inference, 6.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 18.4ms
# Speed: 3.4ms preprocess, 18.4ms inference, 3.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 29.4ms
# Speed: 3.4ms preprocess, 29.4ms inference, 5.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 18.6ms
# Speed: 2.8ms preprocess, 18.6ms inference, 4.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 29.1ms
# Speed: 2.8ms preprocess, 29.1ms inference, 6.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 23.3ms
# Speed: 1.9ms preprocess, 23.3ms inference, 5.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 30.2ms
# Speed: 4.6ms preprocess, 30.2ms inference, 9.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 18.7ms
# Speed: 1.9ms preprocess, 18.7ms inference, 3.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 30.0ms
# Speed: 3.2ms preprocess, 30.0ms inference, 4.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 16.9ms
# Speed: 2.0ms preprocess, 16.9ms inference, 3.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 29.8ms
# Speed: 2.8ms preprocess, 29.8ms inference, 3.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 12.5ms
# Speed: 3.1ms preprocess, 12.5ms inference, 3.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 heads, 29.2ms
# Speed: 2.8ms preprocess, 29.2ms inference, 4.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 19.6ms
# Speed: 2.7ms preprocess, 19.6ms inference, 3.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 55.3ms
# Speed: 3.8ms preprocess, 55.3ms inference, 4.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 42.6ms
# Speed: 5.7ms preprocess, 42.6ms inference, 6.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 37.5ms
# Speed: 2.4ms preprocess, 37.5ms inference, 10.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 22.3ms
# Speed: 2.9ms preprocess, 22.3ms inference, 4.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 28.9ms
# Speed: 2.1ms preprocess, 28.9ms inference, 7.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 15.1ms
# Speed: 2.3ms preprocess, 15.1ms inference, 5.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 28.7ms
# Speed: 2.8ms preprocess, 28.7ms inference, 3.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 12.9ms
# Speed: 2.9ms preprocess, 12.9ms inference, 4.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 heads, 29.0ms
# Speed: 2.4ms preprocess, 29.0ms inference, 3.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 17.6ms
# Speed: 2.4ms preprocess, 17.6ms inference, 2.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 6 heads, 29.4ms
# Speed: 2.7ms preprocess, 29.4ms inference, 6.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 24.9ms
# Speed: 2.2ms preprocess, 24.9ms inference, 4.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 6 heads, 32.3ms
# Speed: 2.8ms preprocess, 32.3ms inference, 4.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 28.4ms
# Speed: 3.4ms preprocess, 28.4ms inference, 4.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 heads, 33.9ms
# Speed: 4.0ms preprocess, 33.9ms inference, 5.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 29.6ms
# Speed: 2.8ms preprocess, 29.6ms inference, 4.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 heads, 31.5ms
# Speed: 2.7ms preprocess, 31.5ms inference, 6.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 27.7ms
# Speed: 2.4ms preprocess, 27.7ms inference, 4.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 heads, 32.3ms
# Speed: 2.8ms preprocess, 32.3ms inference, 6.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 20.2ms
# Speed: 2.1ms preprocess, 20.2ms inference, 5.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 66.1ms
# Speed: 3.3ms preprocess, 66.1ms inference, 5.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 51.7ms
# Speed: 3.0ms preprocess, 51.7ms inference, 7.5ms postprocess per image at shape (1, 3, 288, 512)
#   Saved ./output_videos\tracked_01.mp4
#   Processing 02.mp4
#
# 0: 288x512 (no detections), 29.4ms
# Speed: 4.1ms preprocess, 29.4ms inference, 3.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 1 car, 23.5ms
# Speed: 2.5ms preprocess, 23.5ms inference, 5.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 101.8ms
# Speed: 4.2ms preprocess, 101.8ms inference, 5.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 1 car, 63.8ms
# Speed: 5.7ms preprocess, 63.8ms inference, 48.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 50.8ms
# Speed: 3.1ms preprocess, 50.8ms inference, 3.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 1 car, 64.0ms
# Speed: 4.7ms preprocess, 64.0ms inference, 9.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 69.0ms
# Speed: 4.1ms preprocess, 69.0ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 1 car, 45.6ms
# Speed: 3.7ms preprocess, 45.6ms inference, 6.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 40.8ms
# Speed: 2.8ms preprocess, 40.8ms inference, 3.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 1 car, 48.3ms
# Speed: 4.8ms preprocess, 48.3ms inference, 4.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 41.5ms
# Speed: 3.7ms preprocess, 41.5ms inference, 4.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 1 car, 23.0ms
# Speed: 2.5ms preprocess, 23.0ms inference, 9.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 69.3ms
# Speed: 4.0ms preprocess, 69.3ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 1 car, 32.2ms
# Speed: 3.1ms preprocess, 32.2ms inference, 5.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 43.9ms
# Speed: 3.0ms preprocess, 43.9ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 8 persons, 1 car, 21.5ms
# Speed: 3.7ms preprocess, 21.5ms inference, 5.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 52.4ms
# Speed: 3.0ms preprocess, 52.4ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 persons, 1 car, 54.6ms
# Speed: 5.0ms preprocess, 54.6ms inference, 5.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 45.7ms
# Speed: 5.9ms preprocess, 45.7ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 persons, 1 car, 61.8ms
# Speed: 3.0ms preprocess, 61.8ms inference, 15.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 42.5ms
# Speed: 1.9ms preprocess, 42.5ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 6 persons, 1 car, 36.0ms
# Speed: 3.0ms preprocess, 36.0ms inference, 5.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 42.4ms
# Speed: 2.9ms preprocess, 42.4ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 6 persons, 1 car, 134.3ms
# Speed: 4.2ms preprocess, 134.3ms inference, 27.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 73.1ms
# Speed: 2.9ms preprocess, 73.1ms inference, 3.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 6 persons, 1 car, 36.6ms
# Speed: 3.2ms preprocess, 36.6ms inference, 5.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 71.5ms
# Speed: 8.0ms preprocess, 71.5ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 1 car, 20.1ms
# Speed: 3.1ms preprocess, 20.1ms inference, 5.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 71.0ms
# Speed: 5.0ms preprocess, 71.0ms inference, 4.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 1 car, 43.1ms
# Speed: 6.3ms preprocess, 43.1ms inference, 12.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 68.3ms
# Speed: 2.8ms preprocess, 68.3ms inference, 8.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 1 car, 50.3ms
# Speed: 6.2ms preprocess, 50.3ms inference, 10.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 67.7ms
# Speed: 3.7ms preprocess, 67.7ms inference, 4.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 1 car, 57.7ms
# Speed: 6.9ms preprocess, 57.7ms inference, 4.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 74.7ms
# Speed: 5.7ms preprocess, 74.7ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 1 car, 11.9ms
# Speed: 2.7ms preprocess, 11.9ms inference, 3.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 66.7ms
# Speed: 3.5ms preprocess, 66.7ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 persons, 1 car, 21.2ms
# Speed: 3.9ms preprocess, 21.2ms inference, 6.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 65.0ms
# Speed: 3.4ms preprocess, 65.0ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 persons, 1 car, 17.3ms
# Speed: 2.8ms preprocess, 17.3ms inference, 3.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 61.8ms
# Speed: 2.8ms preprocess, 61.8ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 persons, 1 car, 19.2ms
# Speed: 2.6ms preprocess, 19.2ms inference, 2.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 26.8ms
# Speed: 2.8ms preprocess, 26.8ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 persons, 1 car, 23.6ms
# Speed: 2.4ms preprocess, 23.6ms inference, 5.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 64.5ms
# Speed: 4.3ms preprocess, 64.5ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 1 car, 19.4ms
# Speed: 2.6ms preprocess, 19.4ms inference, 4.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 26.9ms
# Speed: 2.1ms preprocess, 26.9ms inference, 3.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 1 car, 11.9ms
# Speed: 2.9ms preprocess, 11.9ms inference, 2.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 24.7ms
# Speed: 2.0ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 1 car, 14.8ms
# Speed: 2.6ms preprocess, 14.8ms inference, 4.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 24.2ms
# Speed: 1.9ms preprocess, 24.2ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 1 car, 18.5ms
# Speed: 2.1ms preprocess, 18.5ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 25.0ms
# Speed: 2.0ms preprocess, 25.0ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 1 car, 13.3ms
# Speed: 1.9ms preprocess, 13.3ms inference, 5.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 24.8ms
# Speed: 3.3ms preprocess, 24.8ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 1 car, 43.6ms
# Speed: 5.3ms preprocess, 43.6ms inference, 17.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 40.4ms
# Speed: 2.5ms preprocess, 40.4ms inference, 3.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 1 car, 20.5ms
# Speed: 2.9ms preprocess, 20.5ms inference, 4.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 37.0ms
# Speed: 3.3ms preprocess, 37.0ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 1 car, 21.1ms
# Speed: 2.2ms preprocess, 21.1ms inference, 4.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 34.3ms
# Speed: 3.4ms preprocess, 34.3ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 6 persons, 1 car, 21.6ms
# Speed: 2.8ms preprocess, 21.6ms inference, 5.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 31.5ms
# Speed: 2.2ms preprocess, 31.5ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 6 persons, 1 car, 15.5ms
# Speed: 2.4ms preprocess, 15.5ms inference, 3.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 27.8ms
# Speed: 2.2ms preprocess, 27.8ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 6 persons, 1 car, 17.3ms
# Speed: 1.9ms preprocess, 17.3ms inference, 3.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 34.2ms
# Speed: 2.4ms preprocess, 34.2ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 6 persons, 1 car, 20.0ms
# Speed: 2.3ms preprocess, 20.0ms inference, 3.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 23.7ms
# Speed: 2.2ms preprocess, 23.7ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 6 persons, 1 car, 16.2ms
# Speed: 3.6ms preprocess, 16.2ms inference, 3.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 23.6ms
# Speed: 2.7ms preprocess, 23.6ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 11 persons, 1 car, 21.8ms
# Speed: 1.9ms preprocess, 21.8ms inference, 3.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 36.0ms
# Speed: 2.8ms preprocess, 36.0ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 11 persons, 1 car, 21.4ms
# Speed: 2.7ms preprocess, 21.4ms inference, 4.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 92.2ms
# Speed: 5.6ms preprocess, 92.2ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 11 persons, 1 car, 32.9ms
# Speed: 3.3ms preprocess, 32.9ms inference, 5.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 36.0ms
# Speed: 2.3ms preprocess, 36.0ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 9 persons, 1 car, 34.7ms
# Speed: 3.7ms preprocess, 34.7ms inference, 5.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 29.3ms
# Speed: 2.6ms preprocess, 29.3ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 9 persons, 1 car, 35.4ms
# Speed: 4.0ms preprocess, 35.4ms inference, 7.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 27.4ms
# Speed: 2.4ms preprocess, 27.4ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 9 persons, 1 car, 59.5ms
# Speed: 2.5ms preprocess, 59.5ms inference, 16.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 30.2ms
# Speed: 7.3ms preprocess, 30.2ms inference, 3.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 9 persons, 1 car, 85.3ms
# Speed: 2.7ms preprocess, 85.3ms inference, 6.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 83.5ms
# Speed: 4.5ms preprocess, 83.5ms inference, 9.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 9 persons, 1 car, 48.7ms
# Speed: 6.7ms preprocess, 48.7ms inference, 4.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 59.5ms
# Speed: 4.6ms preprocess, 59.5ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 9 persons, 1 car, 13.6ms
# Speed: 2.5ms preprocess, 13.6ms inference, 4.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 32.7ms
# Speed: 2.3ms preprocess, 32.7ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 9 persons, 1 car, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 3.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 32.9ms
# Speed: 2.4ms preprocess, 32.9ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 9 persons, 1 car, 15.5ms
# Speed: 2.6ms preprocess, 15.5ms inference, 3.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 28.3ms
# Speed: 2.3ms preprocess, 28.3ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 6 persons, 1 car, 12.0ms
# Speed: 2.3ms preprocess, 12.0ms inference, 2.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 29.0ms
# Speed: 2.1ms preprocess, 29.0ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 6 persons, 1 car, 11.3ms
# Speed: 2.0ms preprocess, 11.3ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 29.9ms
# Speed: 2.4ms preprocess, 29.9ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 7 persons, 1 car, 12.7ms
# Speed: 2.2ms preprocess, 12.7ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 26.5ms
# Speed: 2.0ms preprocess, 26.5ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 7 persons, 1 car, 13.4ms
# Speed: 2.2ms preprocess, 13.4ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 28.1ms
# Speed: 2.3ms preprocess, 28.1ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 8 persons, 1 car, 13.4ms
# Speed: 2.1ms preprocess, 13.4ms inference, 3.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 25.4ms
# Speed: 2.2ms preprocess, 25.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 8 persons, 1 car, 11.7ms
# Speed: 1.8ms preprocess, 11.7ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 25.1ms
# Speed: 2.0ms preprocess, 25.1ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 7 persons, 1 car, 16.2ms
# Speed: 2.2ms preprocess, 16.2ms inference, 4.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 24.3ms
# Speed: 2.5ms preprocess, 24.3ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 7 persons, 1 car, 14.1ms
# Speed: 2.0ms preprocess, 14.1ms inference, 3.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 24.1ms
# Speed: 2.8ms preprocess, 24.1ms inference, 3.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 persons, 1 car, 14.8ms
# Speed: 2.7ms preprocess, 14.8ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 23.4ms
# Speed: 2.3ms preprocess, 23.4ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 persons, 1 car, 12.5ms
# Speed: 2.3ms preprocess, 12.5ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 24.7ms
# Speed: 1.8ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 persons, 1 car, 12.8ms
# Speed: 3.0ms preprocess, 12.8ms inference, 4.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 23.1ms
# Speed: 2.3ms preprocess, 23.1ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 persons, 1 car, 17.6ms
# Speed: 2.6ms preprocess, 17.6ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 22.8ms
# Speed: 2.5ms preprocess, 22.8ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 persons, 1 car, 24.6ms
# Speed: 3.3ms preprocess, 24.6ms inference, 5.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 23.7ms
# Speed: 3.1ms preprocess, 23.7ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 persons, 1 car, 30.4ms
# Speed: 2.7ms preprocess, 30.4ms inference, 4.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 22.6ms
# Speed: 3.7ms preprocess, 22.6ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 8 persons, 1 car, 18.1ms
# Speed: 1.9ms preprocess, 18.1ms inference, 4.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 24.8ms
# Speed: 3.0ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 8 persons, 1 car, 29.2ms
# Speed: 2.8ms preprocess, 29.2ms inference, 6.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 59.2ms
# Speed: 4.4ms preprocess, 59.2ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 8 persons, 1 car, 22.9ms
# Speed: 3.5ms preprocess, 22.9ms inference, 3.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 31.2ms
# Speed: 3.3ms preprocess, 31.2ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 10 persons, 1 car, 25.4ms
# Speed: 3.3ms preprocess, 25.4ms inference, 4.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 29.7ms
# Speed: 3.9ms preprocess, 29.7ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 9 persons, 1 car, 1 umbrella, 24.0ms
# Speed: 3.1ms preprocess, 24.0ms inference, 5.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 26.6ms
# Speed: 2.6ms preprocess, 26.6ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 9 persons, 1 car, 1 umbrella, 19.9ms
# Speed: 2.8ms preprocess, 19.9ms inference, 5.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 34.2ms
# Speed: 2.8ms preprocess, 34.2ms inference, 3.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 10 persons, 1 car, 1 umbrella, 23.4ms
# Speed: 2.9ms preprocess, 23.4ms inference, 5.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 26.5ms
# Speed: 2.8ms preprocess, 26.5ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 10 persons, 1 car, 1 umbrella, 14.5ms
# Speed: 1.8ms preprocess, 14.5ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 27.1ms
# Speed: 2.1ms preprocess, 27.1ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 10 persons, 1 car, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 3.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 28.6ms
# Speed: 2.4ms preprocess, 28.6ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 10 persons, 1 car, 11.7ms
# Speed: 2.4ms preprocess, 11.7ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 23.8ms
# Speed: 2.1ms preprocess, 23.8ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 9 persons, 1 car, 14.4ms
# Speed: 2.1ms preprocess, 14.4ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 23.2ms
# Speed: 2.3ms preprocess, 23.2ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 9 persons, 1 car, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 23.3ms
# Speed: 2.2ms preprocess, 23.3ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 8 persons, 1 car, 16.2ms
# Speed: 2.1ms preprocess, 16.2ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 33.1ms
# Speed: 2.3ms preprocess, 33.1ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 8 persons, 1 car, 23.2ms
# Speed: 3.5ms preprocess, 23.2ms inference, 4.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 23.2ms
# Speed: 3.7ms preprocess, 23.2ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 8 persons, 1 car, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 23.3ms
# Speed: 2.4ms preprocess, 23.3ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 8 persons, 1 car, 13.0ms
# Speed: 1.9ms preprocess, 13.0ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 24.5ms
# ...
#
# 0: 288x512 9 heads, 35.3ms
# Speed: 3.0ms preprocess, 35.3ms inference, 4.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 13.6ms
# Speed: 2.3ms preprocess, 13.6ms inference, 3.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 13 heads, 36.0ms
# Speed: 2.9ms preprocess, 36.0ms inference, 5.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 19.4ms
# Speed: 3.1ms preprocess, 19.4ms inference, 4.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 12 heads, 37.5ms
# Speed: 2.9ms preprocess, 37.5ms inference, 3.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 21.4ms
# Speed: 2.2ms preprocess, 21.4ms inference, 3.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 9 heads, 36.5ms
# Speed: 2.3ms preprocess, 36.5ms inference, 3.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 10.2ms
# Speed: 2.1ms preprocess, 10.2ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 11 heads, 37.3ms
# Speed: 2.6ms preprocess, 37.3ms inference, 4.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 18.2ms
# Speed: 3.0ms preprocess, 18.2ms inference, 4.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 15 heads, 37.4ms
# Speed: 2.1ms preprocess, 37.4ms inference, 4.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 15.9ms
# Speed: 2.1ms preprocess, 15.9ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 13 heads, 37.5ms
# Speed: 2.2ms preprocess, 37.5ms inference, 5.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 17.2ms
# Speed: 2.9ms preprocess, 17.2ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 9 heads, 37.9ms
# Speed: 3.2ms preprocess, 37.9ms inference, 3.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 21.0ms
# Speed: 2.2ms preprocess, 21.0ms inference, 3.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 17 heads, 37.5ms
# Speed: 2.2ms preprocess, 37.5ms inference, 3.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 1 tv, 13.4ms
# Speed: 2.0ms preprocess, 13.4ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 18 heads, 38.2ms
# Speed: 1.9ms preprocess, 38.2ms inference, 3.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 1 tv, 22.2ms
# Speed: 2.8ms preprocess, 22.2ms inference, 4.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 18 heads, 38.8ms
# Speed: 3.1ms preprocess, 38.8ms inference, 4.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 1 tv, 16.4ms
# Speed: 2.3ms preprocess, 16.4ms inference, 5.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 20 heads, 33.5ms
# Speed: 2.6ms preprocess, 33.5ms inference, 4.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 tv, 18.0ms
# Speed: 2.4ms preprocess, 18.0ms inference, 5.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 13 heads, 33.0ms
# Speed: 3.4ms preprocess, 33.0ms inference, 4.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 tv, 14.6ms
# Speed: 2.4ms preprocess, 14.6ms inference, 3.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 13 heads, 37.3ms
# Speed: 2.3ms preprocess, 37.3ms inference, 4.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 1 tv, 15.4ms
# Speed: 2.3ms preprocess, 15.4ms inference, 5.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 13 heads, 32.6ms
# Speed: 2.3ms preprocess, 32.6ms inference, 3.9ms postprocess per image at shape (1, 3, 288, 512)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 59
#      56 if frame_id % SKIP == 0:
#      57     # Detect heads and bodies
#      58     head_res = head_model(frame, conf=0.15, iou=0.5, imgsz=IMG_SIZE)[0]
# ---> 59     body_res = body_model(frame, conf=0.2,  iou=0.5, imgsz=IMG_SIZE)[0]
#      61     # Collect detections: [x1,y1,x2,y2,conf,cls]
#      62     dets = []
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\engine\model.py:182, in Model.__call__(self, source, stream, **kwargs)
#     153 def __call__(
#     154     self,
#     155     source: Union[str, Path, int, Image.Image, list, tuple, np.ndarray, torch.Tensor] = None,
#     156     stream: bool = False,
#     157     **kwargs: Any,
#     158 ) -> list:
#     159     """
#     160     Alias for the predict method, enabling the model instance to be callable for predictions.
#     161
#    (...)
#     180         ...     print(f"Detected {len(r)} objects in image")
#     181     """
# --> 182     return self.predict(source, stream, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\engine\model.py:552, in Model.predict(self, source, stream, predictor, **kwargs)
#     550 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     551     self.predictor.set_prompts(prompts)
# --> 552 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\engine\predictor.py:218, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     216     return self.stream_inference(source, model, *args, **kwargs)
#     217 else:
# --> 218     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\engine\predictor.py:329, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     327 # Inference
#     328 with profilers[1]:
# --> 329     preds = self.inference(im, *args, **kwargs)
#     330     if self.args.embed:
#     331         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\engine\predictor.py:173, in BasePredictor.inference(self, im, *args, **kwargs)
#     167 """Run inference on a given image using the specified model and arguments."""
#     168 visualize = (
#     169     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     170     if self.args.visualize and (not self.source_type.tensor)
#     171     else False
#     172 )
# --> 173 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\nn\autobackend.py:592, in AutoBackend.forward(self, im, augment, visualize, embed, **kwargs)
#     590 # PyTorch
#     591 if self.pt or self.nn_module:
# --> 592     y = self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#     594 # TorchScript
#     595 elif self.jit:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\nn\tasks.py:115, in BaseModel.forward(self, x, *args, **kwargs)
#     113 if isinstance(x, dict):  # for cases of training and validating while training.
#     114     return self.loss(x, *args, **kwargs)
# --> 115 return self.predict(x, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\nn\tasks.py:133, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     131 if augment:
#     132     return self._predict_augment(x)
# --> 133 return self._predict_once(x, profile, visualize, embed)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\nn\tasks.py:154, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     152 if profile:
#     153     self._profile_one_layer(m, x, dt)
# --> 154 x = m(x)  # run
#     155 y.append(x if m.i in self.save else None)  # save output
#     156 if visualize:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\nn\modules\block.py:302, in C2f.forward(self, x)
#     300 y = list(self.cv1(x).chunk(2, 1))
#     301 y.extend(m(y[-1]) for m in self.m)
# --> 302 return self.cv2(torch.cat(y, 1))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\nn\modules\conv.py:91, in Conv.forward_fuse(self, x)
#      81 def forward_fuse(self, x):
#      82     """
#      83     Apply convolution and activation without batch normalization.
#      84
#    (...)
#      89         (torch.Tensor): Output tensor.
#      90     """
# ---> 91     return self.act(self.conv(x))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# KeyboardInterrupt:

# %%
import os
import pandas as pd
import numpy as np
import cv2
from collections import defaultdict, deque

# ─── Config ───────────────────────────────────────────────────────────────────
video_folder = "./videos"  # Folder with 01.mp4 → 20.mp4
csv_path     = "./output_videos/tracking_log.csv"
out_folder   = "./heatmap_flow_vectors"
os.makedirs(out_folder, exist_ok=True)

FLOW_MEMORY = 5          # Number of past frames to average flow over
MOTION_THRESH = 2        # Minimum movement in pixels to be considered valid flow
VECTOR_LIFE = 10         # How many frames a vector should persist on screen
FLOW_SCALE = 0.4         # Reduce motion vector length (for smoother look)

# ─── Load Data ────────────────────────────────────────────────────────────────
df_all = pd.read_csv(csv_path)

# ─── Process Videos ───────────────────────────────────────────────────────────
for i in range(1, 21):  # Change range as needed
    vid_name = f"{i:02}.mp4"
    in_path  = os.path.join(video_folder, vid_name)
    out_path = os.path.join(out_folder, f"heatmap_flow_{vid_name}")

    if not os.path.isfile(in_path):
        print(f"  Skipping missing video: {vid_name}")
        continue

    df = df_all[df_all["video"] == vid_name].copy()
    if df.empty:
        print(f"  No bounding boxes for: {vid_name}")
        continue

    cap = cv2.VideoCapture(in_path)
    if not cap.isOpened():
        print(f" Error: Cannot open video {vid_name}")
        continue

    fps     = int(cap.get(cv2.CAP_PROP_FPS))
    width   = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height  = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    out = cv2.VideoWriter(out_path, fourcc, fps, (width, height))

    heatmap = np.zeros((height, width), dtype=np.float32)
    track_history = defaultdict(deque)  # track_id → deque of (cx, cy)
    active_vectors = deque()  # persistent arrows

    frame_idx = 0
    print(f"  Processing {vid_name}...")

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        df_frame = df[df["frame_id"] == frame_idx]
        flow_vectors = []

        for _, row in df_frame.iterrows():
            tid = int(row["track_id"])
            x1, y1, x2, y2 = int(row['x1']), int(row['y1']), int(row['x2']), int(row['y2'])
            x1, x2 = np.clip([x1, x2], 0, width - 1)
            y1, y2 = np.clip([y1, y2], 0, height - 1)

            if x2 > x1 and y2 > y1:
                heatmap[y1:y2, x1:x2] += 1

            cx = int((x1 + x2) / 2)
            cy = int((y1 + y2) / 2)

            history = track_history[tid]
            history.append((cx, cy))
            if len(history) > FLOW_MEMORY:
                history.popleft()

            if len(history) >= 2:
                x_coords, y_coords = zip(*history)
                x_avg = int(np.mean(x_coords))
                y_avg = int(np.mean(y_coords))

                dx = x_coords[-1] - x_coords[0]
                dy = y_coords[-1] - y_coords[0]
                dist = np.hypot(dx, dy)

                if dist >= MOTION_THRESH:
                    pt1 = (x_avg, y_avg)
                    pt2 = (int(x_avg + dx * FLOW_SCALE), int(y_avg + dy * FLOW_SCALE))
                    # Store (start, end, life, strength)
                    active_vectors.append((pt1, pt2, VECTOR_LIFE, dist))

        # ─── Smooth Heatmap ─────────────────────────────────────────────────────
        temp_heatmap = cv2.GaussianBlur(heatmap.copy(), (25, 25), 0)
        temp_heatmap = cv2.normalize(temp_heatmap, None, 0, 255, cv2.NORM_MINMAX)
        temp_heatmap = temp_heatmap.astype(np.uint8)
        color_heatmap = cv2.applyColorMap(temp_heatmap, cv2.COLORMAP_JET)
        overlay = cv2.addWeighted(frame, 0.5, color_heatmap, 0.5, 0)

        # ─── Draw Arrows ───────────────────────────────────────────────────────
        new_vectors = deque()
        for pt1, pt2, life, dist in active_vectors:
            if life > 0:
                fade = int(255 * (life / VECTOR_LIFE))  # Fade effect
                color = (fade, fade, fade)  # White to gray
                thickness = 1
                cv2.arrowedLine(overlay, pt1, pt2, color, thickness, tipLength=0.3)
                new_vectors.append((pt1, pt2, life - 1, dist))
        active_vectors = new_vectors

        out.write(overlay)
        frame_idx += 1

    cap.release()
    out.release()
    print(f" Saved: {out_path}")

print(" All enhanced heatmap + clean flow videos created.")
# Out:
# ▶️  Processing 01.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_01.mp4
# ▶️  Processing 02.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_02.mp4
# ▶️  Processing 03.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_03.mp4
# ▶️  Processing 04.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_04.mp4
# ▶️  Processing 05.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_05.mp4
# ▶️  Processing 06.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_06.mp4
# ▶️  Processing 07.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_07.mp4
# ▶️  Processing 08.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_08.mp4
# ▶️  Processing 09.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_09.mp4
# ▶️  Processing 10.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_10.mp4
# ▶️  Processing 11.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_11.mp4
# ▶️  Processing 12.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_12.mp4
# ▶️  Processing 13.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_13.mp4
# ▶️  Processing 14.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_14.mp4
# ▶️  Processing 15.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_15.mp4
# ▶️  Processing 16.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_16.mp4
# ▶️  Processing 17.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_17.mp4
# ▶️  Processing 18.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_18.mp4
# ▶️  Processing 19.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_19.mp4
# ▶️  Processing 20.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_20.mp4
# 🎉 All enhanced heatmap + clean flow videos created.

# %%
#plot trajectories
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
import os

# === CONFIGURATION ===
csv_path = './output_videos/tracking_log.csv'
video_dir = './videos'     # Folder where videos are located
output_dir = './trajectory_outputs'  # Folder to save plots and CSVs
video_prefix = ''
video_ext = '.mp4'
frame_stride = 10
movement_threshold = 30  # pixels

max_videos = 20
# =======================

# Create output directory
os.makedirs(output_dir, exist_ok=True)

# Load tracking data
df = pd.read_csv(csv_path)

if 'video' not in df.columns:
    raise ValueError("CSV must contain a 'video' column for this to work on multiple videos.")

# Compute centers
df['cx'] = (df['x1'] + df['x2']) / 2
df['cy'] = (df['y1'] + df['y2']) / 2

# Function: Determine direction of movement
def get_direction(x0, y0, x1, y1):
    dx, dy = x1 - x0, y1 - y0
    angle = np.degrees(np.arctan2(-dy, dx)) % 360
    if 337.5 <= angle or angle < 22.5:
        return 'E'
    elif 22.5 <= angle < 67.5:
        return 'NE'
    elif 67.5 <= angle < 112.5:
        return 'N'
    elif 112.5 <= angle < 157.5:
        return 'NW'
    elif 157.5 <= angle < 202.5:
        return 'W'
    elif 202.5 <= angle < 247.5:
        return 'SW'
    elif 247.5 <= angle < 292.5:
        return 'S'
    elif 292.5 <= angle < 337.5:
        return 'SE'
    return None

# Process each video
for vid_num in range(1, max_videos + 1):
    vid_name = f'{video_prefix}{vid_num:02d}{video_ext}'
    print(f'\n Processing: {vid_name}')

    vid_df = df[df['video'] == vid_name]

    if vid_df.empty:
        print(f"  No tracking data found for {vid_name}, skipping.")
        continue

    direction_buckets = {
        'N': [], 'NE': [], 'E': [], 'SE': [],
        'S': [], 'SW': [], 'W': [], 'NW': []
    }

    final_csv_rows = []
    selected_trajectories = {}

    for track_id in vid_df['track_id'].dropna().unique():
        group = vid_df[vid_df['track_id'] == track_id].sort_values('frame_id')
        sparse_group = group[group['frame_id'] % frame_stride == 0]

        if len(sparse_group) < 2:
            continue

        coords = sparse_group[['cx', 'cy']].values
        dist = np.sum(np.linalg.norm(coords[1:] - coords[:-1], axis=1))

        if dist < movement_threshold:
            continue

        direction = get_direction(coords[0][0], coords[0][1], coords[-1][0], coords[-1][1])
        if direction:
            direction_buckets[direction].append((track_id, coords, sparse_group))

    for direction, candidates in direction_buckets.items():
        if not candidates:
            continue
        # Choose the longest distance track
        selected = max(candidates, key=lambda x: np.sum(np.linalg.norm(x[1][1:] - x[1][:-1], axis=1)))
        track_id, coords, sparse_group = selected
        selected_trajectories[track_id] = coords
        final_csv_rows.append(sparse_group)

    if not selected_trajectories:
        print(f"  No qualifying trajectories found for {vid_name}")
        continue

    # Save sparse CSV
    sparse_csv_path = os.path.join(output_dir, f'trajectory_{vid_num:02d}.csv')
    pd.concat(final_csv_rows)[['frame_id', 'track_id', 'cx', 'cy']].to_csv(sparse_csv_path, index=False)

    # Plot
    plt.figure(figsize=(10, 8))
    for track_id, points in selected_trajectories.items():
        xs, ys = points[:, 0], points[:, 1]
        plt.plot(xs, ys, label=f'ID {track_id}')
        plt.scatter(xs[-1], ys[-1], s=10)
    plt.title(f'Trajectories in {vid_name}')
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend(loc='upper right', fontsize='x-small')
    plot_path = os.path.join(output_dir, f'trajectory_{vid_num:02d}.png')
    plt.savefig(plot_path)
    plt.close()

    print(f" Saved plot: {plot_path}")
    print(f" Saved CSV: {sparse_csv_path}")
# Out:
#  Processing: 01.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_01.png
#  Saved CSV: /content/trajectory_outputs/trajectory_01.csv
#
#  Processing: 02.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_02.png
#  Saved CSV: /content/trajectory_outputs/trajectory_02.csv
#
#  Processing: 03.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_03.png
#  Saved CSV: /content/trajectory_outputs/trajectory_03.csv
#
#  Processing: 04.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_04.png
#  Saved CSV: /content/trajectory_outputs/trajectory_04.csv
#
#  Processing: 05.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_05.png
#  Saved CSV: /content/trajectory_outputs/trajectory_05.csv
#
#  Processing: 06.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_06.png
#  Saved CSV: /content/trajectory_outputs/trajectory_06.csv
#
#  Processing: 07.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_07.png
#  Saved CSV: /content/trajectory_outputs/trajectory_07.csv
#
#  Processing: 08.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_08.png
#  Saved CSV: /content/trajectory_outputs/trajectory_08.csv
#
#  Processing: 09.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_09.png
#  Saved CSV: /content/trajectory_outputs/trajectory_09.csv
#
#  Processing: 10.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_10.png
#  Saved CSV: /content/trajectory_outputs/trajectory_10.csv
#
#  Processing: 11.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_11.png
#  Saved CSV: /content/trajectory_outputs/trajectory_11.csv
#
#  Processing: 12.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_12.png
#  Saved CSV: /content/trajectory_outputs/trajectory_12.csv
#
#  Processing: 13.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_13.png
#  Saved CSV: /content/trajectory_outputs/trajectory_13.csv
#
#  Processing: 14.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_14.png
#  Saved CSV: /content/trajectory_outputs/trajectory_14.csv
#
#  Processing: 15.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_15.png
#  Saved CSV: /content/trajectory_outputs/trajectory_15.csv
#
#  Processing: 16.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_16.png
#  Saved CSV: /content/trajectory_outputs/trajectory_16.csv
#
#  Processing: 17.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_17.png
#  Saved CSV: /content/trajectory_outputs/trajectory_17.csv
#
#  Processing: 18.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_18.png
#  Saved CSV: /content/trajectory_outputs/trajectory_18.csv
#
#  Processing: 19.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_19.png
#  Saved CSV: /content/trajectory_outputs/trajectory_19.csv
#
#  Processing: 20.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_20.png
#  Saved CSV: /content/trajectory_outputs/trajectory_20.csv

# %%
#panic simulation
import cv2
import pandas as pd
import numpy as np
import os
from tqdm import tqdm

# ==== CONFIG ====
video_folder = './videos'
csv_path = './output_videos/tracking_log.csv'
output_folder = './panic_output_videos'
csv_output_path = './panic_simulation_output.csv'

panic_start_frame = 10
initial_panic_shift = 30
velocity_multiplier = 3
# =================

os.makedirs(output_folder, exist_ok=True)
df = pd.read_csv(csv_path)

# Ensure consistent column names
df.columns = [col.strip().lower() for col in df.columns]

# Final output records
output_records = []

# Loop through all 20 videos
for vid_num in range(1, 21):
    video_filename = f"{vid_num:02d}.mp4"
    video_path = os.path.join(video_folder, video_filename)
    cap = cv2.VideoCapture(video_path)

    if not cap.isOpened():
        print(f" Couldn't open video {video_filename}")
        continue

    fps = cap.get(cv2.CAP_PROP_FPS)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    out_path = os.path.join(output_folder, f"panic_{video_filename}")
    out = cv2.VideoWriter(out_path, cv2.VideoWriter_fourcc(*'mp4v'), fps, (width, height))

    frame_id = 0
    print(f" Processing video {video_filename}")

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        new_frame = frame.copy()
        frame_data = df[(df['video'] == video_filename) & (df['frame_id'] == frame_id)]

        for _, row in frame_data.iterrows():
            if pd.isnull(row[['x1', 'y1', 'x2', 'y2']]).any():
                continue

            x1, y1, x2, y2 = map(int, [row['x1'], row['y1'], row['x2'], row['y2']])
            w, h = x2 - x1, y2 - y1
            if w <= 0 or h <= 0 or x1 < 0 or y1 < 0 or x2 > width or y2 > height:
                continue

            person_patch = frame[y1:y2, x1:x2]

            if frame_id >= panic_start_frame:
                frame_panic_intensity = frame_id - panic_start_frame + 1
                shift = initial_panic_shift + frame_panic_intensity * velocity_multiplier
                jitter = np.random.randint(-5, 6)
                new_x1 = min(width - w, x1 + shift + jitter)
            else:
                new_x1 = x1

            new_x2 = new_x1 + w
            if new_x1 < 0 or new_x2 > width:
                continue

            new_frame[y1:y2, new_x1:new_x2] = person_patch

            # Store updated row
            output_records.append([
                video_filename, frame_id, row['track_id'], new_x1, new_x2, y1, y2
            ])

        out.write(new_frame)
        frame_id += 1

    cap.release()
    out.release()
    print(f" Done: panic_{video_filename}")

# Save final output CSV
columns = ['video', 'frame_id', 'track_id', 'x1', 'x2', 'y1', 'y2']
output_df = pd.DataFrame(output_records, columns=columns)
output_df.to_csv(csv_output_path, index=False)
print(f" CSV saved to {csv_output_path}")
# Out:
# 🚀 Processing video 01.mp4
# ✅ Done: panic_01.mp4
# 🚀 Processing video 02.mp4
# ✅ Done: panic_02.mp4
# 🚀 Processing video 03.mp4
# ✅ Done: panic_03.mp4
# 🚀 Processing video 04.mp4
# ✅ Done: panic_04.mp4
# 🚀 Processing video 05.mp4
# ✅ Done: panic_05.mp4
# 🚀 Processing video 06.mp4
# ✅ Done: panic_06.mp4
# 🚀 Processing video 07.mp4
# ✅ Done: panic_07.mp4
# 🚀 Processing video 08.mp4
# ✅ Done: panic_08.mp4
# 🚀 Processing video 09.mp4
# ✅ Done: panic_09.mp4
# 🚀 Processing video 10.mp4
# ✅ Done: panic_10.mp4
# 🚀 Processing video 11.mp4
# ✅ Done: panic_11.mp4
# 🚀 Processing video 12.mp4
# ✅ Done: panic_12.mp4
# 🚀 Processing video 13.mp4
# ✅ Done: panic_13.mp4
# 🚀 Processing video 14.mp4
# ✅ Done: panic_14.mp4
# 🚀 Processing video 15.mp4
# ✅ Done: panic_15.mp4
# 🚀 Processing video 16.mp4
# ✅ Done: panic_16.mp4
# 🚀 Processing video 17.mp4
# ✅ Done: panic_17.mp4
# 🚀 Processing video 18.mp4
# ✅ Done: panic_18.mp4
# 🚀 Processing video 19.mp4
# ✅ Done: panic_19.mp4
# 🚀 Processing video 20.mp4
# ✅ Done: panic_20.mp4
# 📁 CSV saved to panic_simulation_output.csv

# %%
#heatmap for panic videos
import os
import pandas as pd
import numpy as np
import cv2
from collections import defaultdict, deque

# ─── Config ───────────────────────────────────────────────────────────────────
video_folder = "./panic_output_videos"  # Folder with 01.mp4 → 20.mp4
csv_path     = "./panic_simulation_output.csv"
out_folder   = "./panic_heatmap_flow_vectors"
os.makedirs(out_folder, exist_ok=True)

FLOW_MEMORY = 5          # Number of past frames to average flow over
MOTION_THRESH = 2        # Minimum movement in pixels to be considered valid flow
VECTOR_LIFE = 10         # How many frames a vector should persist on screen
FLOW_SCALE = 0.4         # Reduce motion vector length (for smoother look)

# ─── Load Data ────────────────────────────────────────────────────────────────
df_all = pd.read_csv(csv_path)

# ─── Process Videos ───────────────────────────────────────────────────────────
for i in range(1, 21):  # Change range as needed
    vid_name = f"panic_{i:02}.mp4"
    col_name = f"{i:02}.mp4"
    in_path  = os.path.join(video_folder, vid_name)
    out_path = os.path.join(out_folder, f"heatmap_flow_{vid_name}")

    if not os.path.isfile(in_path):
        print(f"  Skipping missing video: {vid_name}")
        continue

    df = df_all[df_all["video"] == col_name].copy()
    if df.empty:
        print(f"  No bounding boxes for: {vid_name}")
        continue

    cap = cv2.VideoCapture(in_path)
    if not cap.isOpened():
        print(f" Error: Cannot open video {vid_name}")
        continue

    fps     = int(cap.get(cv2.CAP_PROP_FPS))
    width   = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height  = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    out = cv2.VideoWriter(out_path, fourcc, fps, (width, height))

    heatmap = np.zeros((height, width), dtype=np.float32)
    track_history = defaultdict(deque)  # track_id → deque of (cx, cy)
    active_vectors = deque()  # persistent arrows

    frame_idx = 0
    print(f"  Processing {vid_name}...")

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        df_frame = df[df["frame_id"] == frame_idx]
        flow_vectors = []

        for _, row in df_frame.iterrows():
            tid = int(row["track_id"])
            x1, y1, x2, y2 = int(row['x1']), int(row['y1']), int(row['x2']), int(row['y2'])
            x1, x2 = np.clip([x1, x2], 0, width - 1)
            y1, y2 = np.clip([y1, y2], 0, height - 1)

            if x2 > x1 and y2 > y1:
                heatmap[y1:y2, x1:x2] += 1

            cx = int((x1 + x2) / 2)
            cy = int((y1 + y2) / 2)

            history = track_history[tid]
            history.append((cx, cy))
            if len(history) > FLOW_MEMORY:
                history.popleft()

            if len(history) >= 2:
                x_coords, y_coords = zip(*history)
                x_avg = int(np.mean(x_coords))
                y_avg = int(np.mean(y_coords))

                dx = x_coords[-1] - x_coords[0]
                dy = y_coords[-1] - y_coords[0]
                dist = np.hypot(dx, dy)

                if dist >= MOTION_THRESH:
                    pt1 = (x_avg, y_avg)
                    pt2 = (int(x_avg + dx * FLOW_SCALE), int(y_avg + dy * FLOW_SCALE))
                    # Store (start, end, life, strength)
                    active_vectors.append((pt1, pt2, VECTOR_LIFE, dist))

        # ─── Smooth Heatmap ─────────────────────────────────────────────────────
        temp_heatmap = cv2.GaussianBlur(heatmap.copy(), (25, 25), 0)
        temp_heatmap = cv2.normalize(temp_heatmap, None, 0, 255, cv2.NORM_MINMAX)
        temp_heatmap = temp_heatmap.astype(np.uint8)
        color_heatmap = cv2.applyColorMap(temp_heatmap, cv2.COLORMAP_JET)
        overlay = cv2.addWeighted(frame, 0.5, color_heatmap, 0.5, 0)

        # ─── Draw Arrows ───────────────────────────────────────────────────────
        new_vectors = deque()
        for pt1, pt2, life, dist in active_vectors:
            if life > 0:
                fade = int(255 * (life / VECTOR_LIFE))  # Fade effect
                color = (fade, fade, fade)  # White to gray
                thickness = 1
                cv2.arrowedLine(overlay, pt1, pt2, color, thickness, tipLength=0.3)
                new_vectors.append((pt1, pt2, life - 1, dist))
        active_vectors = new_vectors

        out.write(overlay)
        frame_idx += 1

    cap.release()
    out.release()
    print(f" Saved: {out_path}")

print(" All enhanced heatmap + clean flow videos created.")
# Out:
# ▶️  Processing panic_01.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_01.mp4
# ▶️  Processing panic_02.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_02.mp4
# ▶️  Processing panic_03.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_03.mp4
# ▶️  Processing panic_04.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_04.mp4
# ▶️  Processing panic_05.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_05.mp4
# ▶️  Processing panic_06.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_06.mp4
# ▶️  Processing panic_07.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_07.mp4
# ▶️  Processing panic_08.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_08.mp4
# ▶️  Processing panic_09.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_09.mp4
# ▶️  Processing panic_10.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_10.mp4
# ▶️  Processing panic_11.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_11.mp4
# ▶️  Processing panic_12.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_12.mp4
# ▶️  Processing panic_13.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_13.mp4
# ▶️  Processing panic_14.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_14.mp4
# ▶️  Processing panic_15.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_15.mp4
# ▶️  Processing panic_16.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_16.mp4
# ▶️  Processing panic_17.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_17.mp4
# ▶️  Processing panic_18.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_18.mp4
# ▶️  Processing panic_19.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_19.mp4
# ▶️  Processing panic_20.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_20.mp4
# 🎉 All enhanced heatmap + clean flow videos created.
